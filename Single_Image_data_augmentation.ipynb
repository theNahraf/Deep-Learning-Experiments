# %% [markdown]
# <a href="https://colab.research.google.com/github/theNahraf/Deep-Learning-Experiments/blob/main/Single_Image_data_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from IPython import get_ipython
from IPython.display import display

# %%
img = image.load_img('/content/train/cat.jpg')

# %%
img #type is not numpy
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x408>

# %%
datagen = ImageDataGenerator(
    rotation_range=30,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    width_shift_range=0.2,
    height_shift_range=0.2,
    #ass pass wale pixel
    fill_mode='nearest'
)

# %%
img = image.img_to_array(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (408, 612, 3)

# %%
input_batch = img.reshape(1,200,200,3)

# %%
from os import statvfs_result
i=0
#for one image flow is use
for output in datagen.flow(input_batch, batch_size=1, save_to_dir='aug'):
  i = i + 1
  if i == 10:
    break
